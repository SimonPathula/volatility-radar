# %%
import os
os.chdir("D:/Projects/volatility-radar")

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("data/processed/full_labeled.csv")
df.head()
# Out:
#          date     time currency                      event impact    pair  \
# 0  2021-01-15   1:15pm      EUR       French Final CPI m/m    Low  EURUSD
# 1  2021-01-15   1:15pm      EUR  French Gov Budget Balance    Low  EURUSD
# 2  2021-01-15   3:30pm      EUR              Trade Balance    Low  EURUSD
# 3  2021-01-19  12:30pm      EUR       German Final CPI m/m    Low  EURUSD
# 4  2021-01-19   2:30pm      EUR            Current Account    Low  EURUSD
#
#       open     high     low    close        actual      previous  \
# 0  1.21540  1.21625  1.2072  1.20749  2.000000e-01  2.000000e-01
# 1  1.21540  1.21625  1.2072  1.20749 -1.768000e+11 -1.599000e+11
# 2  1.21540  1.21625  1.2072  1.20749  2.510000e+10  2.520000e+10
# 3  1.20744  1.21450  1.2072  1.21280  5.000000e-01  5.000000e-01
# 4  1.20744  1.21450  1.2072  1.21280  2.460000e+10  2.560000e+10
#
#        surprise  impact_score  label  rolling_std    return
# 0  0.000000e+00             1      5     0.425123 -0.650815
# ...

# %%
df.dtypes
# Out:
# date                str
# time                str
# currency            str
# event               str
# impact              str
# pair                str
# open            float64
# high            float64
# low             float64
# close           float64
# actual          float64
# previous        float64
# surprise        float64
# impact_score      int64
# label             int64
# rolling_std     float64
# return          float64
# dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output= False, drop= True)

cat_column = df['event']

encoded = encoder.fit_transform(df[cat_column])

print(encoder.get_feature_names_out())

print(encoded)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 7
#       3 encoder = OneHotEncoder(sparse_output= False, drop= True)
#       5 cat_column = df['event']
# ----> 7 encoded = encoder.fit_transform(df[cat_column])
#       9 print(encoder.get_feature_names_out())
#      11 print(encoded)
#
# File d:\Projects\volatility-radar\.venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File d:\Projects\volatility-radar\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
# ...
