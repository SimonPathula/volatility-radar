# %%
import os
os.chdir("D:/Projects/volatility-radar")

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("data/processed_v2/merged.csv")

# %%
print(df[['daily_range', 'candle_body', 'upper_wick', 'lower_wick']].describe())
print(df[['daily_range', 'candle_body', 'upper_wick', 'lower_wick']].isna().sum())
# Out:
#        daily_range  candle_body   upper_wick   lower_wick
# count  4023.000000  4023.000000  4023.000000  4023.000000
# mean      0.412853     0.205570     0.093473     0.113810
# std       0.721412     0.443629     0.201356     0.242034
# min       0.000100     0.000000     0.000000     0.000000
# 25%       0.006940     0.002340     0.001340     0.001270
# 50%       0.010660     0.006050     0.003070     0.002960
# 75%       0.703000     0.206500     0.110000     0.125000
# max       6.923000     5.516000     2.690000     2.629000
# daily_range    0
# candle_body    0
# upper_wick     0
# lower_wick     0
# dtype: int64

# %%
df.columns.to_list()
# Out:
# ['pair',
#  'date',
#  'open',
#  'high',
#  'low',
#  'close',
#  'max_up_pips',
#  'max_down_pips',
#  'max_profit',
#  'max_loss',
#  'daily_return',
#  'return_3d',
#  'return_5d',
#  'return_10d',
#  'rolling_std_5',
#  'rolling_std_10',
#  'rolling_std_20',
#  'rsi_14',
#  'atr_14',
#  'momentum_5d',
#  'momentum_10d',
#  'dist_from_mean_20d',
#  'daily_range',
#  'candle_body',
#  'upper_wick',
#  'lower_wick',
#  'high_impact_count',
#  'medium_impact_count',
#  'low_impact_count',
#  'max_z_score',
#  'sum_signal',
#  'dominant_direction',
#  'max_surprise_z',
#  'sum_signal_surprise',
#  'label']

# %%
print(df.shape)
print(df.isna().sum())
print(df['pair'].value_counts())
# Out:
# (4023, 35)
# pair                   0
# date                   0
# open                   0
# high                   0
# low                    0
# close                  0
# max_up_pips            0
# max_down_pips          0
# max_profit             0
# max_loss               0
# daily_return           0
# return_3d              0
# return_5d              0
# return_10d             0
# rolling_std_5          0
# rolling_std_10         0
# rolling_std_20         0
# rsi_14                 0
# atr_14                 0
# momentum_5d            0
# momentum_10d           0
# dist_from_mean_20d     0
# daily_range            0
# candle_body            0
# upper_wick             0
# lower_wick             0
# high_impact_count      0
# medium_impact_count    0
# low_impact_count       0
# max_z_score            0
# sum_signal             0
# dominant_direction     0
# max_surprise_z         0
# sum_signal_surprise    0
# label                  0
# dtype: int64
# pair
# EURUSD    1341
# ...

# %%
df = pd.read_csv("data/final_cleaned_data/full_features.csv")
df.shape
# Out:
# (4023, 40)

# %%
df.columns.to_list()
# Out:
# ['pair',
#  'date',
#  'open',
#  'high',
#  'low',
#  'close',
#  'day_of_week',
#  'month',
#  'week_of_year',
#  'is_month_end',
#  'is_month_start',
#  'max_up_pips',
#  'max_down_pips',
#  'max_profit',
#  'max_loss',
#  'daily_return',
#  'return_3d',
#  'return_5d',
#  'return_10d',
#  'rolling_std_5',
#  'rolling_std_10',
#  'rolling_std_20',
#  'rsi_14',
#  'atr_14',
#  'momentum_5d',
#  'momentum_10d',
#  'dist_from_mean_20d',
#  'daily_range',
#  'candle_body',
#  'upper_wick',
#  'lower_wick',
#  'high_impact_count',
#  'medium_impact_count',
#  'low_impact_count',
#  'max_z_score',
#  'sum_signal',
#  'dominant_direction',
#  'max_surprise_z',
#  'sum_signal_surprise',
#  'label']
