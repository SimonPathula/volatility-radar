# %%
import os
os.chdir("D:/Projects/volatility-radar")

# %%
import pandas as pd

df = pd.read_csv('data/final_cleaned_data/full_features.csv')
df['date'] = pd.to_datetime(df['date'])

unique_dates = df['date'].sort_values().unique()

print(f"Total rows: {len(df)}")
print(f"Unique dates: {len(unique_dates)}")
print(f"Date range: {unique_dates[0]} → {unique_dates[-1]}")
print(f"Pairs: {df['pair'].unique()}")
print(f"Rows per pair:\n{df['pair'].value_counts()}")
# Out:
# Total rows: 4023
# Unique dates: 1341
# Date range: 2021-01-21 00:00:00 → 2026-03-12 00:00:00
# Pairs: [0 1 2]
# Rows per pair:
# pair
# 0    1341
# 1    1341
# 2    1341
# Name: count, dtype: int64
