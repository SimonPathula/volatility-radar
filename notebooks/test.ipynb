# %%
import pandas as pd

df = pd.read_csv(r"D:\projects\volatility-radar\data\raw\economic_calendar_raw.csv")
print(df[['date','time']].head(10))
# Out:
#         date    time
# 0  Mon Jan 4  6:00am
# 1  Mon Jan 4  1:45pm
# 2  Mon Jan 4  2:15pm
# 3  Mon Jan 4  2:20pm
# 4  Mon Jan 4  2:25pm
# 5  Mon Jan 4  2:30pm
# 6  Mon Jan 4  3:00pm
# 7  Mon Jan 4     NaN
# 8  Mon Jan 4     NaN
# 9  Mon Jan 4     NaN

# %%
head = pd.read_csv(r"D:\projects\volatility-radar\data\processed\usdjpy_forex.csv")[["date"]].head()
print(head)
# Out:
#          date
# 0  2021-01-04
# 1  2021-01-04
# 2  2021-01-04
# 3  2021-01-05
# 4  2021-01-05

# %%
head = pd.read_csv(r"D:\projects\volatility-radar\data\processed\usdjpy_forex.csv")[["date"]].tail()
print(head)
# Out:
#             date
# 6832  2026-03-13
# 6833  2026-03-13
# 6834  2026-03-13
# 6835  2026-03-13
# 6836  2026-03-13
